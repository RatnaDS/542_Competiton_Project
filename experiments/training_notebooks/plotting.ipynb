# %%
import os
import sys
sys.path.append("..//..//..//ece542-competition-project")

# %%
from ml_utils.plotter import plot_curves

# %%
train_loss = [1.33,0.62,0.40,0.34,0.28,0.24,0.20,0.17,0.16,0.15,0.15,0.14,0.13,0.13,0.12,0.12,0.12,0.11,0.11,0.11,0.11,0.11,
             0.11,0.11,0.10,0.10,0.10,0.10,0.10,0.10]

# %%
train_acc = [0.38,0.73,0.81,0.85,0.88,0.91,0.92,0.94,0.94,0.94,0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.96,0.96,0.96,0.96,0.96,
            0.96,0.96,0.96,0.96,0.96,0.96,0.96,0.96]

# %%
val_loss = [1.07,1.03,0.75,0.85,0.61,0.61,0.64,0.70,0.50,0.54,0.49,0.51,0.51,0.43,0.43,0.45,0.44,0.43,0.45,0.45,0.44,0.43,
           0.43,0.43,0.44,0.44,0.44,0.44,0.44,0.44]

# %%
val_acc = [0.52,0.46,0.69,0.60,0.74,0.77,0.74,0.71,0.81,0.79,0.81,0.81,0.81,0.83,0.83,0.83,0.83,0.84,0.83,0.83,0.83,0.83,
          0.84,0.83,0.83,0.83,0.83,0.83,0.83,0.83]

# %%
plot_curves(train_loss,val_loss,train_acc,val_acc,save_path = "./",save = True)
